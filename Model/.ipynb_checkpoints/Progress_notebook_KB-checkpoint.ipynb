# %% [markdown]
# ## Perth Basin Case Study using Loop2Flopy

# %%
import numpy as np
import pandas as pd
import numbers

# %% [markdown]
# ### Importing Borehole Data

# %%
bore_info = pd.read_excel("../Geological_data/Dwer_data\Formation picks.xls",sheet_name = "bore_info")
strat_info = pd.read_excel("../Geological_data/Dwer_data\Formation picks.xls",sheet_name = "strat_info")
bore_info
# Out:
#       Easting   Northing                 Source    ID  Ground  TQ  Tr Tkm Tk  \
# 0      -999.0     -999.0  PRAMS Formation Picks  JWS1    22.0  45   -   -  -
# 1      -999.0     -999.0  PRAMS Formation Picks    P7    67.0   6   -   -  -
# 2      -999.0     -999.0  PRAMS Formation Picks    WP     4.0  30   -   -  -
# 3    329743.0  6617059.0  PRAMS Formation Picks   ML8    39.0  24   -   -  -
# 4    387569.0  6613192.0  PRAMS Formation Picks   ML2   206.0   3   -   -  -
# ..        ...        ...                    ...   ...     ...  ..  ..  .. ..
# 407  387523.0  6403674.0  PRAMS Formation Picks  AM65     2.0   9  57   -  -
# 408  403632.0  6402890.0  PRAMS Formation Picks  AM69    41.0   2   -   -  -
# 409  382835.0  6402182.0  PRAMS Formation Picks  AM67    11.0  21  44   -  -
# 410  390782.0  6398413.0  PRAMS Formation Picks  AM68     9.0   8  58   -  -
# 411  399256.0  6397116.0  PRAMS Formation Picks  AM70    21.0   4   -   -  -
#
#     Tkc  ... Kwlp Kwlw Kwlm  Kws  Kwg  Kpc Kps Kpo   Jy   Jc
# 0     -  ...  236  342  429  484  555    -   -   -  822    -
# 1     -  ...    -  256  277  350    -  555   -   -    -    -
# 2     -  ...    -   67  207  324  399    -   -   -  449    -
# 3     -  ...    -    -    -    -    -    -   -   -    -    -
# 4     -  ...   27  298  346    -    -  762   -   -    -    -
# ..   ..  ...  ...  ...  ...  ...  ...  ...  ..  ..  ...  ...
# 407   -  ...    -   69  188  208    -    -   -   -    -  363
# 408   -  ...    -    -   60    -    -    -   -   -    -  417
# 409   -  ...    -   96  186  246    -    -   -   -    -  375
# 410   -  ...    -   80  176  203  287    -   -   -    -  327
# 411   -  ...    -    -  103    -    -    -   -   -    -  505
#
# [412 rows x 27 columns]

# %% [markdown]
# ### Filter data
# Crop to desired area and delete columns of less than 2 data points

# %%
df = bore_info.copy()
x0, x1, y0, y1, z0, z1 = 355000, 390000, 6527000, 6537000, -1200, 200 
#x0, x1, y0, y1, z0, z1 = 355000, 390000, 6527000, 6537000, -1200, 200 # Whole Block
df = df.loc[(df['Northing'] >= y0)] 
df = df.loc[(df['Northing'] <= y1)]
#df = df.loc[(df['Easting'] <= x1)]
df = df.drop(['Source'], axis=1)
#df = df.drop(['Tr','Tkm', 'Tk','Tkc','Jc','Kcom','Kps','Kpo','Kpc','Kcoh','Kcp'], axis=1)
# I think we need to keep this general so that we can apply it everywhere...
#df = df.reset_index(drop=True)

df
# Out:
#      Easting   Northing     ID  Ground  TQ Tr Tkm Tk Tkc  Kcl  ... Kwlp Kwlw  \
# 31  367173.0  6535521.0    AM3   27.00  39  -   -  -   -   44  ...  167  606
# 32  383790.0  6535459.0    AM4   50.00  41  -   -  -   -    -  ...   92  143
# 33  374139.0  6535349.0    TPK   60.00  42  -   -  -   -    -  ...    -  168
# 34  392430.0  6534424.0    GY1   82.48  30  -   -  -   -    -  ...    -    -
# 35  362041.0  6534075.0    GB4    9.00  45  -   -  -   -   53  ...  175  535
# 36  373194.0  6533955.0    GB3   31.00  34  -   -  -   -    -  ...   40  235
# 37  407026.0  6533780.0    PER  185.00   -  -   -  -   -    -  ...  157    -
# 38  396819.0  6533529.0  CHER1  105.00   1  -   -  -   -    -  ...    -  135
# 39  366379.0  6533124.0    GB2   58.00  46  -   -  -   -    -  ...   97  152
# 40  399706.0  6532768.0   MBRK  105.00   5  -   -  -   -    -  ...  134    -
# 41  396339.0  6532249.0   GG75  115.00   -  -   -  -   -    -  ...  110  171
# 42  384139.0  6532149.0  SN786  135.00   -  -   -  -   -    -  ...   81  135
# 43  356924.0  6531829.0    AM1   53.00  99  -   -  -   -  157  ...  222  499
# 44  396539.0  6531749.0   GG85  100.00   -  -   -  -   -    -  ...   79    -
# 45  395149.0  6531407.0    GB5  103.00   2  -   -  -   -    -  ...   18   82
# 46  401021.0  6531105.0   MCK1  127.00   5  -   -  -   -    -  ...  180  270
# 47  401258.0  6530836.0    GB1  117.00  14  -   -  -   -    -  ...  184  316
# 48  400739.0  6530349.0  MART2  170.00   2  -   -  -   -    -  ...  188    -
# 49  365646.0  6529649.0    AM2   36.00  61  -   -  -   -   96  ...  220  605
# 50  386985.0  6529614.0    AM6   64.00  28  -   -  -   -    -  ...    -   80
# 51  398539.0  6529149.0   DELE  155.00   2  -   -  -   -    -  ...  138  254
# 52  398539.0  6528649.0   GASB  115.00   -  -   -  -   -    -  ...  108  189
# 53  372107.1  6528279.3   AM76   31.57  59  -   -  -   -    -  ...  263  557
# 54  400539.0  6528049.0   PB5A  135.00   -  -   -  -   -    -  ...   22  317
# 55  375480.0  6527971.0    AM5   52.00  54  -   -  -   -    -  ...    -  242
# 56  398727.0  6527718.0    AM7  102.00   3  -   -  -   -    -  ...  168  306
# 57  400789.0  6527699.0    TTD   95.00   4  -   -  -   -    -  ...  122  180
# 58  400639.0  6527649.0   POL2  100.00   4  -   -  -   -    -  ...  195  267
# 59  399819.0  6527569.0    PB3   91.00   -  -   -  -   -    -  ...   73  171
# 60  398039.0  6527349.0   AVON  120.00   -  -   -  -   -    -  ...   99  231
#
#    Kwlm  Kws  Kwg  Kpc  Kps  Kpo   Jy Jc
# 31  729    -    -    -    -    -    -  -
# 32  200  204  332    -    -    -  549  -
# 33    -    -    -    -    -    -    -  -
# 34    -    -    -  552    -    -  762  -
# 35    -    -    -    -    -    -    -  -
# 36  360  376  405    -    -    -  719  -
# 37    -    -    -    -    -    -    -  -
# 38    -    -    -    -    -    -    -  -
# 39  168    -    -    -    -    -  509  -
# 40    -    -    -    -    -    -    -  -
# 41    -    -    -  275    -    -    -  -
# 42    -    -    -    -    -    -    -  -
# 43  505  517    -  680    -    -    -  -
# 44    -    -    -    -    -    -    -  -
# 45    -    -    -  380  451  514  517  -
# 46    -    -    -    -    -    -    -  -
# 47    -    -    -    -    -    -    -  -
# 48    -    -    -    -    -    -    -  -
# 49  775  803  829    -    -    -  881  -
# 50    -    -    -    -    -    -  300  -
# 51    -    -    -    -    -    -    -  -
# 52    -    -    -    -    -    -    -  -
# 53  647    -    -    -    -    -    -  -
# 54    -    -    -    -    -    -    -  -
# 55  277    -    -    -    -    -  302  -
# 56    -    -    -  721    -    -    -  -
# 57    -    -    -    -    -    -    -  -
# 58    -    -    -    -    -    -    -  -
# 59    -    -    -    -    -    -    -  -
# 60    -    -    -    -    -    -    -  -
#
# [30 rows x 26 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Plan of data points
plt.scatter(df.Easting, df.Northing)
plt.xlabel('Easting')
plt.ylabel('Northing')
i = 0
for (xi, yi) in zip(df.Easting, df.Northing):
    plt.text(xi, yi, df.ID[i], va='bottom', ha='center')
    i += 1
#plt.plot([fx1, fx2], [fy1, fy2])
#plt.plot(fault_center[0], fault_center[1], 'o')
#plt.xlim(x0,x1)
#plt.ylim(y0,y1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\loop3denv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# ~\Anaconda3\envs\loop3denv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\envs\loop3denv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35000\1392057341.py in <cell line: 9>()
#       8 i = 0
#       9 for (xi, yi) in zip(df.Easting, df.Northing):
# ---> 10     plt.text(xi, yi, df.ID[i], va='bottom', ha='center')
#      11     i += 1
#      12 #plt.plot([fx1, fx2], [fy1, fy2])
#
# ~\Anaconda3\envs\loop3denv\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     979
#     980         elif key_is_scalar:
# --> 981             return self._get_value(key)
#     982
#     983         if is_hashable(key):
#
# ~\Anaconda3\envs\loop3denv\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1087
#    1088         # Similar to Index.get_value, but we do not fall back to positional
# -> 1089         loc = self.index.get_loc(label)
#    1090         return self.index._get_values_for_loc(self, loc, label)
#    1091
#
# ~\Anaconda3\envs\loop3denv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
lithcodes = list(df.columns.values[3:])         # Make a list of formations  
df.Easting = pd.to_numeric(df.Easting)
df.Northing = pd.to_numeric(df.Northing)
df.Ground = pd.to_numeric(df.Ground)
print(lithcodes)
# Out:
# ['Ground', 'TQ', 'Tr', 'Tkm', 'Tk', 'Tkc', 'Kcl', 'Kcp', 'Kcg', 'Kcm', 'Kcom', 'Kcok', 'Kcoh', 'Kwlp', 'Kwlw', 'Kwlm', 'Kws', 'Kwg', 'Kpc', 'Kps', 'Kpo', 'Jy', 'Jc']

# %%
strat = []

for i, lith in enumerate(lithcodes):
    index = i
    lithid = i-1
    val = 120 - i*100 # arbitrary isolvalue
    sequence = strat_info.loc[strat_info['unit'] == lith, 'sequence'].item()
    R = strat_info.loc[strat_info['unit'] == lith, 'R'].item()/255
    G = strat_info.loc[strat_info['unit'] == lith, 'G'].item()/255
    B = strat_info.loc[strat_info['unit'] == lith, 'B'].item()/255
    strat.append([index, lithid, lith, sequence, val, [round(R,2),round(G,2),round(B,2)]])
strat = pd.DataFrame(strat)
strat.columns =['index','lithid','lithcode','sequences','vals','color']
strat
# Out:
#     index  lithid lithcode   sequences  vals               color
# 0       0      -1   Ground  Quaternary   120     [1.0, 1.0, 1.0]
# 1       1       0       TQ  Quaternary    20     [1.0, 1.0, 0.0]
# 2       2       1       Tr    Tertiary   -80   [0.73, 0.6, 0.58]
# 3       3       2      Tkm    Tertiary  -180     [1.0, 0.6, 0.2]
# 4       4       3       Tk    Tertiary  -280  [1.12, 0.32, 0.16]
# 5       5       4      Tkc    Tertiary  -380     [1.0, 0.6, 0.2]
# 6       6       5      Kcl    Coolyena  -480    [0.67, 0.8, 0.0]
# 7       7       6      Kcp    Coolyena  -580  [0.77, 0.84, 0.61]
# 8       8       7      Kcg    Coolyena  -680   [0.67, 0.85, 0.6]
# 9       9       8      Kcm    Coolyena  -780  [0.67, 0.78, 0.71]
# 10     10       9     Kcom    Coolyena  -880   [0.66, 0.64, 0.0]
# 11     11      10     Kcok    Coolyena  -980     [1.0, 0.8, 0.6]
# 12     12      11     Kcoh    Coolyena -1080     [1.0, 0.8, 0.8]
# 13     13      12     Kwlp     Warnbro -1180     [0.8, 1.0, 0.2]
# 14     14      13     Kwlw     Warnbro -1280     [0.6, 0.8, 0.0]
# 15     15      14     Kwlm     Warnbro -1380     [0.4, 0.6, 0.0]
# 16     16      15      Kws     Warnbro -1480  [0.58, 0.54, 0.33]
# 17     17      16      Kwg     Warnbro -1580   [0.31, 0.38, 0.2]
# 18     18      17      Kpc  Yarragadee -1680  [0.68, 0.73, 0.95]
# 19     19      18      Kps  Yarragadee -1780  [0.68, 0.73, 0.95]
# 20     20      19      Kpo  Yarragadee -1880    [0.46, 0.5, 0.9]
# 21     21      20       Jy  Yarragadee -1980  [0.33, 0.55, 0.83]
# 22     22      21       Jc  Yarragadee -2080   [0.0, 0.63, 0.72]

# %% [markdown]
# ### Make lithology table for Loop

# %%
data_list = df.values.tolist()             # Turn data into a list of lists
formatted_data = []

### Okay. We also neet to establish is the unit is the last in the well. JP added the EOH for these units. So, see be;low for my alternative....

for i in range(len(data_list)): #iterate for each row
    
    boreid = data_list[i][2]
    easting, northing = data_list[i][0], data_list[i][1]
    groundlevel = data_list[i][3]    
    
    # set orientation data for corner wells
    if boreid == 'AM1' or boreid == 'AM6':
        gx, gy, gz = 0., 0., 1.
    else: 
        gx, gy, gz = np.nan, np.nan, np.nan
        
    # Add data for groundlevel
    val = strat.vals[0]
    formatted_data.append([boreid, easting, northing, groundlevel, val, 'Ground', 'Quaternary', gx, gy, gz]) 

    # Add data row for each lithology
    count = 1
    for j in range(4,df.shape[1]-1): #iterate through each formation until before Yarragade

        # Add lithology
        if isinstance(data_list[i][j], numbers.Number) == True:    
            bottom    = groundlevel - float(data_list[i][j])  # Ground surface - formation bottom (mbgl)
            val       = strat.vals[count]                      # designated isovalue
            lithid    = lithcodes[count]                       # lithology id 
            feat_name = strat.sequences[count]                 # sequence name
            formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, gx, gy, gz])    
   
    #For absent units, put in a dummy point 1m higher than last detected unit (and with UC, should form a pinchout)    
        else:
            bottom    = current_bottom - 0.01*count
            val       = strat.vals[count]                      # designated isovalue
            lithid    = lithcodes[count]                       # lithology id 
            feat_name = strat.sequences[count]                 # sequence name
            formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, gx, gy, gz])

        current_bottom = np.copy(bottom) 
        #count+=1
        
data = pd.DataFrame(formatted_data)
data.columns =['ID','X','Y','Z','val','lithcode','feature_name', 'gx', 'gy', 'gz']

data["strike"]=np.nan
data["dip"]=np.nan
data["nx"]=np.nan
data["ny"]=np.nan
data["nz"]=np.nan

sequences = data['feature_name'].unique()
data
# Out:
#        ID         X          Y       Z  val lithcode feature_name  gx  gy  gz  \
# 0     AM3  367173.0  6535521.0   27.00  120   Ground   Quaternary NaN NaN NaN
# 1     AM3  367173.0  6535521.0  -12.00   20       TQ   Quaternary NaN NaN NaN
# 2     AM3  367173.0  6535521.0  -12.01   20       TQ   Quaternary NaN NaN NaN
# 3     AM3  367173.0  6535521.0  -12.02   20       TQ   Quaternary NaN NaN NaN
# 4     AM3  367173.0  6535521.0  -12.03   20       TQ   Quaternary NaN NaN NaN
# ..    ...       ...        ...     ...  ...      ...          ...  ..  ..  ..
# 655  AVON  398039.0  6527349.0 -111.03   20       TQ   Quaternary NaN NaN NaN
# 656  AVON  398039.0  6527349.0 -111.04   20       TQ   Quaternary NaN NaN NaN
# 657  AVON  398039.0  6527349.0 -111.05   20       TQ   Quaternary NaN NaN NaN
# 658  AVON  398039.0  6527349.0 -111.06   20       TQ   Quaternary NaN NaN NaN
# 659  AVON  398039.0  6527349.0 -111.07   20       TQ   Quaternary NaN NaN NaN
#
#      strike  dip  nx  ny  nz
# 0       NaN  NaN NaN NaN NaN
# 1       NaN  NaN NaN NaN NaN
# 2       NaN  NaN NaN NaN NaN
# 3       NaN  NaN NaN NaN NaN
# 4       NaN  NaN NaN NaN NaN
# ..      ...  ...  ..  ..  ..
# 655     NaN  NaN NaN NaN NaN
# 656     NaN  NaN NaN NaN NaN
# 657     NaN  NaN NaN NaN NaN
# 658     NaN  NaN NaN NaN NaN
# 659     NaN  NaN NaN NaN NaN
#
# [660 rows x 15 columns]

# %%
#filtered_df = data[data.ID == 'AM5'] 
for lith in lithcodes:
    filtered_df = data[data.lithcode == lith] 
    print('\n Lithology = ', lith, '\n\n', filtered_df[['ID','X','Y','Z','val','lithcode','feature_name',  'gx', 'gy', 'gz']])
# Out:
#  Lithology =  Ground
#
#          ID         X          Y       Z  val lithcode feature_name   gx   gy  \
# 0      AM3  367173.0  6535521.0   27.00  120   Ground   Quaternary  NaN  NaN
# 22     AM4  383790.0  6535459.0   50.00  120   Ground   Quaternary  NaN  NaN
# 44     TPK  374139.0  6535349.0   60.00  120   Ground   Quaternary  NaN  NaN
# 66     GY1  392430.0  6534424.0   82.48  120   Ground   Quaternary  NaN  NaN
# 88     GB4  362041.0  6534075.0    9.00  120   Ground   Quaternary  NaN  NaN
# 110    GB3  373194.0  6533955.0   31.00  120   Ground   Quaternary  NaN  NaN
# 132    PER  407026.0  6533780.0  185.00  120   Ground   Quaternary  NaN  NaN
# 154  CHER1  396819.0  6533529.0  105.00  120   Ground   Quaternary  NaN  NaN
# 176    GB2  366379.0  6533124.0   58.00  120   Ground   Quaternary  NaN  NaN
# 198   MBRK  399706.0  6532768.0  105.00  120   Ground   Quaternary  NaN  NaN
# 220   GG75  396339.0  6532249.0  115.00  120   Ground   Quaternary  NaN  NaN
# 242  SN786  384139.0  6532149.0  135.00  120   Ground   Quaternary  NaN  NaN
# 264    AM1  356924.0  6531829.0   53.00  120   Ground   Quaternary  0.0  0.0
# 286   GG85  396539.0  6531749.0  100.00  120   Ground   Quaternary  NaN  NaN
# 308    GB5  395149.0  6531407.0  103.00  120   Ground   Quaternary  NaN  NaN
# 330   MCK1  401021.0  6531105.0  127.00  120   Ground   Quaternary  NaN  NaN
# 352    GB1  401258.0  6530836.0  117.00  120   Ground   Quaternary  NaN  NaN
# 374  MART2  400739.0  6530349.0  170.00  120   Ground   Quaternary  NaN  NaN
# 396    AM2  365646.0  6529649.0   36.00  120   Ground   Quaternary  NaN  NaN
# 418    AM6  386985.0  6529614.0   64.00  120   Ground   Quaternary  0.0  0.0
# 440   DELE  398539.0  6529149.0  155.00  120   Ground   Quaternary  NaN  NaN
# 462   GASB  398539.0  6528649.0  115.00  120   Ground   Quaternary  NaN  NaN
# 484   AM76  372107.1  6528279.3   31.57  120   Ground   Quaternary  NaN  NaN
# 506   PB5A  400539.0  6528049.0  135.00  120   Ground   Quaternary  NaN  NaN
# 528    AM5  375480.0  6527971.0   52.00  120   Ground   Quaternary  NaN  NaN
# 550    AM7  398727.0  6527718.0  102.00  120   Ground   Quaternary  NaN  NaN
# 572    TTD  400789.0  6527699.0   95.00  120   Ground   Quaternary  NaN  NaN
# 594   POL2  400639.0  6527649.0  100.00  120   Ground   Quaternary  NaN  NaN
# 616    PB3  399819.0  6527569.0   91.00  120   Ground   Quaternary  NaN  NaN
# 638   AVON  398039.0  6527349.0  120.00  120   Ground   Quaternary  NaN  NaN
#
#       gz
# 0    NaN
# 22   NaN
# 44   NaN
# 66   NaN
# 88   NaN
# 110  NaN
# 132  NaN
# 154  NaN
# 176  NaN
# 198  NaN
# 220  NaN
# 242  NaN
# 264  1.0
# 286  NaN
# 308  NaN
# 330  NaN
# 352  NaN
# 374  NaN
# 396  NaN
# 418  1.0
# 440  NaN
# 462  NaN
# 484  NaN
# 506  NaN
# 528  NaN
# 550  NaN
# 572  NaN
# 594  NaN
# 616  NaN
# 638  NaN
#
#  Lithology =  TQ
#
#         ID         X          Y       Z  val lithcode feature_name  gx  gy  gz
# 1     AM3  367173.0  6535521.0  -12.00   20       TQ   Quaternary NaN NaN NaN
# 2     AM3  367173.0  6535521.0  -12.01   20       TQ   Quaternary NaN NaN NaN
# 3     AM3  367173.0  6535521.0  -12.02   20       TQ   Quaternary NaN NaN NaN
# 4     AM3  367173.0  6535521.0  -12.03   20       TQ   Quaternary NaN NaN NaN
# 5     AM3  367173.0  6535521.0  -12.04   20       TQ   Quaternary NaN NaN NaN
# ..    ...       ...        ...     ...  ...      ...          ...  ..  ..  ..
# 655  AVON  398039.0  6527349.0 -111.03   20       TQ   Quaternary NaN NaN NaN
# 656  AVON  398039.0  6527349.0 -111.04   20       TQ   Quaternary NaN NaN NaN
# 657  AVON  398039.0  6527349.0 -111.05   20       TQ   Quaternary NaN NaN NaN
# 658  AVON  398039.0  6527349.0 -111.06   20       TQ   Quaternary NaN NaN NaN
# 659  AVON  398039.0  6527349.0 -111.07   20       TQ   Quaternary NaN NaN NaN
#
# [630 rows x 10 columns]
#
#  Lithology =  Tr
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Tkm
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Tk
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Tkc
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kcl
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kcp
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kcg
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kcm
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kcom
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kcok
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kcoh
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kwlp
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kwlw
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kwlm
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kws
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kwg
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kpc
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kps
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kpo
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Jy
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Jc
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []

# %%
#Okay, let me vocalise, or type, what is in my mind...
# So we treat the four parts as their own thing...
# then we make the unconformities feature names....
#Also, on the phone with JP, he said the last number is the end of hole (EOH) 


data_list = df.values.tolist()             # Turn data into a list of lists
formatted_data = []
for i in range(len(data_list)): #iterate for each row
    end = False
    # okay, first we will establish the max value (i.e. the end of the hole)
    stuff = []
    for j in range(3,25,1):
        if isinstance(data_list[i][j], numbers.Number) == True:
            stuff.append(data_list[i][j])
            
    EOH = max(stuff)
    print(EOH)
        
    boreid = data_list[i][2]
    easting, northing = data_list[i][0], data_list[i][1]
    groundlevel = data_list[i][3]    
    # First channp.nan, np.nan, np.nange - we can get the norms from the geophys data...
    gx, gy, gz = np.nan, np.nan, np.nan
        
    # Add data for groundlevel
    val = strat.vals[0]
    formatted_data.append([boreid, easting, northing, groundlevel, val, 'Ground', 'Quaternary', gx, gy, gz]) #eventually we cn get this from a dem...
    current_bottom = np.copy(groundlevel)
    
    #okay... lets see if the TQ boundary exists... 
    # JP question - Say in SN786, how you have logged it, do you mean the Pinjar is at the surface?
    #thought 2 - we will just have a DEM eventaully I imagine... so ground could be an unconformity if we have something other than TQ at the surface?
    # but in the current framework:
    if isinstance(data_list[i][4], numbers.Number) == True:
        bottom    = groundlevel - float(data_list[i][4])  # Ground surface - TQ (mbgl)
        val       = strat.vals[1]                      # designated isovalue
        lithid    = lithcodes[1]                       # lithology id 
        feat_name = strat.sequences[1]                 # sequence name
        formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, gx, gy, gz])
        current_bottom = np.copy(bottom)
    
    # I know, I know, there isn't any of the tertiary one here, but in being thorough...
    
    for j in range(5,9,1):
        if isinstance(data_list[i][j], numbers.Number) == True:
            if data_list[i][j] < EOH:
                bottom    = groundlevel -float(data_list[i][j])  # Ground surface - TQ (mbgl)
                val       = strat.vals[j-3]                      # designated isovalue
            else:
                bottom    = np.copy(current_bottom) # Ground surface - TQ (mbgl)
                val       = strat.vals[j-4]                      # designated isovalue
                end = True
                                          
            lithid    = lithcodes[j-3 ]                       # lithology id 
            feat_name = strat.sequences[j-3]                 # sequence name
            formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, gx, gy, gz])    
            current_bottom = np.copy(bottom)

                                   
    # Teriary unconformity
    if end == False:
        bottom = current_bottom
        val = 0.
        lithid = 'Tert_base'
        feat_name = 'Tertiary_unconformity'
        formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, 0., 0., 1.])
                                          
    # Fighting, out of the perth Basin by way of San Jose Calfornia: The Coolyeena Formation!!!!
    
    for j in range(9,16,1):
        if isinstance(data_list[i][j], numbers.Number) == True:
            if data_list[i][j] < EOH:
                bottom    = groundlevel -float(data_list[i][j])  # Ground surface - TQ (mbgl)
                val       = strat.vals[j-3]                      # designated isovalue
            else:
                bottom    = np.copy(current_bottom) # Ground surface - TQ (mbgl)
                val       = strat.vals[j-4]                      # designated isovalue     
                end = True
            lithid    = lithcodes[j-3 ]                       # lithology id 
            feat_name = strat.sequences[j-3]                 # sequence name
            formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, gx, gy, gz])    
            current_bottom = np.copy(bottom)                                          
                                          
    # Unconfiormity
    if end == False:
        bottom = current_bottom
        val = 0.
        lithid = 'Cool_base'
        feat_name = 'CoolUC'
        formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, 0., 0., 1.])      
                                          
    for j in range(16,21,1):
        if isinstance(data_list[i][j], numbers.Number) == True:
            if data_list[i][j] < EOH:
                bottom    = groundlevel -float(data_list[i][j])  # Ground surface - TQ (mbgl)
                val       = strat.vals[j-3]                      # designated isovalue
            else:
                bottom    = np.copy(current_bottom) # Ground surface - TQ (mbgl)
                val       = strat.vals[j-4]                      # designated isovalue     
                end = True
            lithid    = lithcodes[j-3 ]                       # lithology id 
            feat_name = strat.sequences[j-3]                 # sequence name
            formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, gx, gy, gz])    
            current_bottom = np.copy(bottom)  
    # Unconfiormity
    if end == False:
        bottom = current_bottom
        val = 0.
        lithid = 'Warn_base'
        feat_name = 'WarnUC'
        formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, 0., 0., 1.])  
        
    gx, gy, gz = 0., 0., 1.
    for j in range(21,26,1):
        if isinstance(data_list[i][j], numbers.Number) == True:
            if data_list[i][j] < EOH:
                bottom    = groundlevel -float(data_list[i][j])  # Ground surface - TQ (mbgl)
                val       = strat.vals[j-3]                      # designated isovalue
            else:
                bottom    = np.copy(current_bottom) # Ground surface - TQ (mbgl)
                val       = strat.vals[j-4]                      # designated isovalue     
                end = True
            lithid    = lithcodes[j-3 ]                       # lithology id 
            feat_name = strat.sequences[j-3]                 # sequence name
            formatted_data.append([boreid, easting, northing, bottom, val, lithid, feat_name, gx, gy, gz])    
            current_bottom = np.copy(bottom)  

data = pd.DataFrame(formatted_data)
data.columns =['ID','X','Y','Z','val','lithcode','feature_name', 'gx', 'gy', 'gz']

data["strike"]=np.nan
data["dip"]=np.nan
data["nx"]=np.nan
data["ny"]=np.nan
data["nz"]=np.nan

sequences = data['feature_name'].unique()
data

for lith in lithcodes:
    filtered_df = data[data.lithcode == lith] 
    print('\n Lithology = ', lith, '\n\n', filtered_df[['ID','X','Y','Z','val','lithcode','feature_name',  'gx', 'gy', 'gz']])
# Out:
# 729
# 549
# 168
# 762
# 535
# 719
# 185.0
# 135
# 509
# 134
# 275
# 135.0
# 680
# 100.0
# 517
# 270
# 316
# 188
# 881
# 300
# 254
# 189
# 647
# 317
# 302
# 721
# 180
# 267
# 171
# 231
#
#  Lithology =  Ground
#
#          ID         X          Y      Z    val lithcode feature_name  gx  gy  \
# 0      AM3  367173.0  6535521.0   27.0  120.0   Ground   Quaternary NaN NaN
# 11     AM4  383790.0  6535459.0   50.0  120.0   Ground   Quaternary NaN NaN
# 22     TPK  374139.0  6535349.0   60.0  120.0   Ground   Quaternary NaN NaN
# 27     GY1  392430.0  6534424.0  82.48  120.0   Ground   Quaternary NaN NaN
# 34     GB4  362041.0  6534075.0    9.0  120.0   Ground   Quaternary NaN NaN
# 44     GB3  373194.0  6533955.0   31.0  120.0   Ground   Quaternary NaN NaN
# 55     PER  407026.0  6533780.0  185.0  120.0   Ground   Quaternary NaN NaN
# 65   CHER1  396819.0  6533529.0  105.0  120.0   Ground   Quaternary NaN NaN
# 70     GB2  366379.0  6533124.0   58.0  120.0   Ground   Quaternary NaN NaN
# 79    MBRK  399706.0  6532768.0  105.0  120.0   Ground   Quaternary NaN NaN
# 88    GG75  396339.0  6532249.0  115.0  120.0   Ground   Quaternary NaN NaN
# 95   SN786  384139.0  6532149.0  135.0  120.0   Ground   Quaternary NaN NaN
# 100    AM1  356924.0  6531829.0   53.0  120.0   Ground   Quaternary NaN NaN
# 113   GG85  396539.0  6531749.0  100.0  120.0   Ground   Quaternary NaN NaN
# 118    GB5  395149.0  6531407.0  103.0  120.0   Ground   Quaternary NaN NaN
# 129   MCK1  401021.0  6531105.0  127.0  120.0   Ground   Quaternary NaN NaN
# 139    GB1  401258.0  6530836.0  117.0  120.0   Ground   Quaternary NaN NaN
# 148  MART2  400739.0  6530349.0  170.0  120.0   Ground   Quaternary NaN NaN
# 157    AM2  365646.0  6529649.0   36.0  120.0   Ground   Quaternary NaN NaN
# 172    AM6  386985.0  6529614.0   64.0  120.0   Ground   Quaternary NaN NaN
# 179   DELE  398539.0  6529149.0  155.0  120.0   Ground   Quaternary NaN NaN
# 189   GASB  398539.0  6528649.0  115.0  120.0   Ground   Quaternary NaN NaN
# 196   AM76  372107.1  6528279.3  31.57  120.0   Ground   Quaternary NaN NaN
# 205   PB5A  400539.0  6528049.0  135.0  120.0   Ground   Quaternary NaN NaN
# 214    AM5  375480.0  6527971.0   52.0  120.0   Ground   Quaternary NaN NaN
# 222    AM7  398727.0  6527718.0  102.0  120.0   Ground   Quaternary NaN NaN
# 231    TTD  400789.0  6527699.0   95.0  120.0   Ground   Quaternary NaN NaN
# 241   POL2  400639.0  6527649.0  100.0  120.0   Ground   Quaternary NaN NaN
# 251    PB3  399819.0  6527569.0   91.0  120.0   Ground   Quaternary NaN NaN
# 257   AVON  398039.0  6527349.0  120.0  120.0   Ground   Quaternary NaN NaN
#
#      gz
# 0   NaN
# 11  NaN
# 22  NaN
# 27  NaN
# 34  NaN
# 44  NaN
# 55  NaN
# 65  NaN
# 70  NaN
# 79  NaN
# 88  NaN
# 95  NaN
# 100 NaN
# 113 NaN
# 118 NaN
# 129 NaN
# 139 NaN
# 148 NaN
# 157 NaN
# 172 NaN
# 179 NaN
# 189 NaN
# 196 NaN
# 205 NaN
# 214 NaN
# 222 NaN
# 231 NaN
# 241 NaN
# 251 NaN
# 257 NaN
#
#  Lithology =  TQ
#
#          ID         X          Y      Z   val lithcode feature_name  gx  gy  gz
# 1      AM3  367173.0  6535521.0  -12.0  20.0       TQ   Quaternary NaN NaN NaN
# 12     AM4  383790.0  6535459.0    9.0  20.0       TQ   Quaternary NaN NaN NaN
# 23     TPK  374139.0  6535349.0   18.0  20.0       TQ   Quaternary NaN NaN NaN
# 28     GY1  392430.0  6534424.0  52.48  20.0       TQ   Quaternary NaN NaN NaN
# 35     GB4  362041.0  6534075.0  -36.0  20.0       TQ   Quaternary NaN NaN NaN
# 45     GB3  373194.0  6533955.0   -3.0  20.0       TQ   Quaternary NaN NaN NaN
# 66   CHER1  396819.0  6533529.0  104.0  20.0       TQ   Quaternary NaN NaN NaN
# 71     GB2  366379.0  6533124.0   12.0  20.0       TQ   Quaternary NaN NaN NaN
# 80    MBRK  399706.0  6532768.0  100.0  20.0       TQ   Quaternary NaN NaN NaN
# 101    AM1  356924.0  6531829.0  -46.0  20.0       TQ   Quaternary NaN NaN NaN
# 119    GB5  395149.0  6531407.0  101.0  20.0       TQ   Quaternary NaN NaN NaN
# 130   MCK1  401021.0  6531105.0  122.0  20.0       TQ   Quaternary NaN NaN NaN
# 140    GB1  401258.0  6530836.0  103.0  20.0       TQ   Quaternary NaN NaN NaN
# 149  MART2  400739.0  6530349.0  168.0  20.0       TQ   Quaternary NaN NaN NaN
# 158    AM2  365646.0  6529649.0  -25.0  20.0       TQ   Quaternary NaN NaN NaN
# 173    AM6  386985.0  6529614.0   36.0  20.0       TQ   Quaternary NaN NaN NaN
# 180   DELE  398539.0  6529149.0  153.0  20.0       TQ   Quaternary NaN NaN NaN
# 197   AM76  372107.1  6528279.3 -27.43  20.0       TQ   Quaternary NaN NaN NaN
# 215    AM5  375480.0  6527971.0   -2.0  20.0       TQ   Quaternary NaN NaN NaN
# 223    AM7  398727.0  6527718.0   99.0  20.0       TQ   Quaternary NaN NaN NaN
# 232    TTD  400789.0  6527699.0   91.0  20.0       TQ   Quaternary NaN NaN NaN
# 242   POL2  400639.0  6527649.0   96.0  20.0       TQ   Quaternary NaN NaN NaN
#
#  Lithology =  Tr
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Tkm
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Tk
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Tkc
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kcl
#
#        ID         X          Y      Z    val lithcode feature_name  gx  gy  gz
# 3    AM3  367173.0  6535521.0  -17.0 -480.0      Kcl     Coolyena NaN NaN NaN
# 37   GB4  362041.0  6534075.0  -44.0 -480.0      Kcl     Coolyena NaN NaN NaN
# 103  AM1  356924.0  6531829.0 -104.0 -480.0      Kcl     Coolyena NaN NaN NaN
# 160  AM2  365646.0  6529649.0  -60.0 -480.0      Kcl     Coolyena NaN NaN NaN
#
#  Lithology =  Kcp
#
#          ID         X          Y      Z    val lithcode feature_name  gx  gy  \
# 57     PER  407026.0  6533780.0  164.0 -580.0      Kcp     Coolyena NaN NaN
# 82    MBRK  399706.0  6532768.0   93.0 -580.0      Kcp     Coolyena NaN NaN
# 132   MCK1  401021.0  6531105.0  113.0 -580.0      Kcp     Coolyena NaN NaN
# 142    GB1  401258.0  6530836.0   99.0 -580.0      Kcp     Coolyena NaN NaN
# 151  MART2  400739.0  6530349.0  131.0 -580.0      Kcp     Coolyena NaN NaN
# 182   DELE  398539.0  6529149.0  148.0 -580.0      Kcp     Coolyena NaN NaN
# 207   PB5A  400539.0  6528049.0  128.0 -580.0      Kcp     Coolyena NaN NaN
# 234    TTD  400789.0  6527699.0   83.0 -580.0      Kcp     Coolyena NaN NaN
# 244   POL2  400639.0  6527649.0   91.0 -580.0      Kcp     Coolyena NaN NaN
#
#      gz
# 57  NaN
# 82  NaN
# 132 NaN
# 142 NaN
# 151 NaN
# 182 NaN
# 207 NaN
# 234 NaN
# 244 NaN
#
#  Lithology =  Kcg
#
#          ID         X          Y      Z    val lithcode feature_name  gx  gy  \
# 4      AM3  367173.0  6535521.0  -33.0 -680.0      Kcg     Coolyena NaN NaN
# 38     GB4  362041.0  6534075.0  -57.0 -680.0      Kcg     Coolyena NaN NaN
# 58     PER  407026.0  6533780.0  159.0 -680.0      Kcg     Coolyena NaN NaN
# 83    MBRK  399706.0  6532768.0   85.0 -680.0      Kcg     Coolyena NaN NaN
# 104    AM1  356924.0  6531829.0 -114.0 -680.0      Kcg     Coolyena NaN NaN
# 133   MCK1  401021.0  6531105.0  104.0 -680.0      Kcg     Coolyena NaN NaN
# 143    GB1  401258.0  6530836.0   94.0 -680.0      Kcg     Coolyena NaN NaN
# 152  MART2  400739.0  6530349.0  125.0 -680.0      Kcg     Coolyena NaN NaN
# 161    AM2  365646.0  6529649.0  -84.0 -680.0      Kcg     Coolyena NaN NaN
# 183   DELE  398539.0  6529149.0  146.0 -680.0      Kcg     Coolyena NaN NaN
# 199   AM76  372107.1  6528279.3 -71.43 -680.0      Kcg     Coolyena NaN NaN
# 208   PB5A  400539.0  6528049.0  124.0 -680.0      Kcg     Coolyena NaN NaN
# 235    TTD  400789.0  6527699.0   77.0 -680.0      Kcg     Coolyena NaN NaN
# 245   POL2  400639.0  6527649.0   86.0 -680.0      Kcg     Coolyena NaN NaN
#
#      gz
# 4   NaN
# 38  NaN
# 58  NaN
# 83  NaN
# 104 NaN
# 133 NaN
# 143 NaN
# 152 NaN
# 161 NaN
# 183 NaN
# 199 NaN
# 208 NaN
# 235 NaN
# 245 NaN
#
#  Lithology =  Kcm
#
#          ID         X          Y      Z    val lithcode feature_name  gx  gy  \
# 5      AM3  367173.0  6535521.0  -43.0 -780.0      Kcm     Coolyena NaN NaN
# 39     GB4  362041.0  6534075.0  -77.0 -780.0      Kcm     Coolyena NaN NaN
# 59     PER  407026.0  6533780.0  129.0 -780.0      Kcm     Coolyena NaN NaN
# 84    MBRK  399706.0  6532768.0   71.0 -780.0      Kcm     Coolyena NaN NaN
# 105    AM1  356924.0  6531829.0 -165.0 -780.0      Kcm     Coolyena NaN NaN
# 134   MCK1  401021.0  6531105.0   84.0 -780.0      Kcm     Coolyena NaN NaN
# 153  MART2  400739.0  6530349.0  118.0 -780.0      Kcm     Coolyena NaN NaN
# 162    AM2  365646.0  6529649.0  -87.0 -780.0      Kcm     Coolyena NaN NaN
# 184   DELE  398539.0  6529149.0  136.0 -780.0      Kcm     Coolyena NaN NaN
# 191   GASB  398539.0  6528649.0  109.0 -780.0      Kcm     Coolyena NaN NaN
# 209   PB5A  400539.0  6528049.0  105.0 -780.0      Kcm     Coolyena NaN NaN
# 236    TTD  400789.0  6527699.0   67.0 -780.0      Kcm     Coolyena NaN NaN
# 246   POL2  400639.0  6527649.0   70.0 -780.0      Kcm     Coolyena NaN NaN
#
#      gz
# 5   NaN
# 39  NaN
# 59  NaN
# 84  NaN
# 105 NaN
# 134 NaN
# 153 NaN
# 162 NaN
# 184 NaN
# 191 NaN
# 209 NaN
# 236 NaN
# 246 NaN
#
#  Lithology =  Kcom
#
#       ID         X          Y     Z    val lithcode feature_name  gx  gy  gz
# 60  PER  407026.0  6533780.0  75.0 -880.0     Kcom     Coolyena NaN NaN NaN
#
#  Lithology =  Kcok
#
#          ID         X          Y       Z    val lithcode feature_name  gx  gy  \
# 6      AM3  367173.0  6535521.0  -137.0 -980.0     Kcok     Coolyena NaN NaN
# 40     GB4  362041.0  6534075.0  -156.0 -980.0     Kcok     Coolyena NaN NaN
# 61     PER  407026.0  6533780.0    33.0 -980.0     Kcok     Coolyena NaN NaN
# 85    MBRK  399706.0  6532768.0    58.0 -980.0     Kcok     Coolyena NaN NaN
# 135   MCK1  401021.0  6531105.0    31.0 -980.0     Kcok     Coolyena NaN NaN
# 144    GB1  401258.0  6530836.0    17.0 -980.0     Kcok     Coolyena NaN NaN
# 154  MART2  400739.0  6530349.0    41.0 -980.0     Kcok     Coolyena NaN NaN
# 163    AM2  365646.0  6529649.0  -174.0 -980.0     Kcok     Coolyena NaN NaN
# 185   DELE  398539.0  6529149.0    93.0 -980.0     Kcok     Coolyena NaN NaN
# 192   GASB  398539.0  6528649.0    94.0 -980.0     Kcok     Coolyena NaN NaN
# 200   AM76  372107.1  6528279.3 -176.43 -980.0     Kcok     Coolyena NaN NaN
# 210   PB5A  400539.0  6528049.0    32.0 -980.0     Kcok     Coolyena NaN NaN
# 225    AM7  398727.0  6527718.0    82.0 -980.0     Kcok     Coolyena NaN NaN
# 237    TTD  400789.0  6527699.0    20.0 -980.0     Kcok     Coolyena NaN NaN
# 247   POL2  400639.0  6527649.0    25.0 -980.0     Kcok     Coolyena NaN NaN
# 253    PB3  399819.0  6527569.0    53.0 -980.0     Kcok     Coolyena NaN NaN
#
#      gz
# 6   NaN
# 40  NaN
# 61  NaN
# 85  NaN
# 135 NaN
# 144 NaN
# 154 NaN
# 163 NaN
# 185 NaN
# 192 NaN
# 200 NaN
# 210 NaN
# 225 NaN
# 237 NaN
# 247 NaN
# 253 NaN
#
#  Lithology =  Kcoh
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []
#
#  Lithology =  Kwlp
#
#          ID         X          Y       Z     val lithcode feature_name  gx  gy  \
# 8      AM3  367173.0  6535521.0  -140.0 -1180.0     Kwlp      Warnbro NaN NaN
# 15     AM4  383790.0  6535459.0   -42.0 -1180.0     Kwlp      Warnbro NaN NaN
# 42     GB4  362041.0  6534075.0  -166.0 -1180.0     Kwlp      Warnbro NaN NaN
# 48     GB3  373194.0  6533955.0    -9.0 -1180.0     Kwlp      Warnbro NaN NaN
# 63     PER  407026.0  6533780.0    28.0 -1180.0     Kwlp      Warnbro NaN NaN
# 74     GB2  366379.0  6533124.0   -39.0 -1180.0     Kwlp      Warnbro NaN NaN
# 87    MBRK  399706.0  6532768.0    58.0 -1080.0     Kwlp      Warnbro NaN NaN
# 91    GG75  396339.0  6532249.0     5.0 -1180.0     Kwlp      Warnbro NaN NaN
# 98   SN786  384139.0  6532149.0    54.0 -1180.0     Kwlp      Warnbro NaN NaN
# 107    AM1  356924.0  6531829.0  -169.0 -1180.0     Kwlp      Warnbro NaN NaN
# 116   GG85  396539.0  6531749.0    21.0 -1180.0     Kwlp      Warnbro NaN NaN
# 122    GB5  395149.0  6531407.0    85.0 -1180.0     Kwlp      Warnbro NaN NaN
# 137   MCK1  401021.0  6531105.0   -53.0 -1180.0     Kwlp      Warnbro NaN NaN
# 146    GB1  401258.0  6530836.0   -67.0 -1180.0     Kwlp      Warnbro NaN NaN
# 156  MART2  400739.0  6530349.0    41.0 -1080.0     Kwlp      Warnbro NaN NaN
# 165    AM2  365646.0  6529649.0  -184.0 -1180.0     Kwlp      Warnbro NaN NaN
# 187   DELE  398539.0  6529149.0    17.0 -1180.0     Kwlp      Warnbro NaN NaN
# 194   GASB  398539.0  6528649.0     7.0 -1180.0     Kwlp      Warnbro NaN NaN
# 202   AM76  372107.1  6528279.3 -231.43 -1180.0     Kwlp      Warnbro NaN NaN
# 212   PB5A  400539.0  6528049.0   113.0 -1180.0     Kwlp      Warnbro NaN NaN
# 227    AM7  398727.0  6527718.0   -66.0 -1180.0     Kwlp      Warnbro NaN NaN
# 239    TTD  400789.0  6527699.0   -27.0 -1180.0     Kwlp      Warnbro NaN NaN
# 249   POL2  400639.0  6527649.0   -95.0 -1180.0     Kwlp      Warnbro NaN NaN
# 255    PB3  399819.0  6527569.0    18.0 -1180.0     Kwlp      Warnbro NaN NaN
# 260   AVON  398039.0  6527349.0    21.0 -1180.0     Kwlp      Warnbro NaN NaN
#
#      gz
# 8   NaN
# 15  NaN
# 42  NaN
# 48  NaN
# 63  NaN
# 74  NaN
# 87  NaN
# 91  NaN
# 98  NaN
# 107 NaN
# 116 NaN
# 122 NaN
# 137 NaN
# 146 NaN
# 156 NaN
# 165 NaN
# 187 NaN
# 194 NaN
# 202 NaN
# 212 NaN
# 227 NaN
# 239 NaN
# 249 NaN
# 255 NaN
# 260 NaN
#
#  Lithology =  Kwlw
#
#          ID         X          Y       Z     val lithcode feature_name  gx  gy  \
# 9      AM3  367173.0  6535521.0  -579.0 -1280.0     Kwlw      Warnbro NaN NaN
# 16     AM4  383790.0  6535459.0   -93.0 -1280.0     Kwlw      Warnbro NaN NaN
# 26     TPK  374139.0  6535349.0    18.0 -1180.0     Kwlw      Warnbro NaN NaN
# 43     GB4  362041.0  6534075.0  -166.0 -1180.0     Kwlw      Warnbro NaN NaN
# 49     GB3  373194.0  6533955.0  -204.0 -1280.0     Kwlw      Warnbro NaN NaN
# 69   CHER1  396819.0  6533529.0   104.0 -1180.0     Kwlw      Warnbro NaN NaN
# 75     GB2  366379.0  6533124.0   -94.0 -1280.0     Kwlw      Warnbro NaN NaN
# 92    GG75  396339.0  6532249.0   -56.0 -1280.0     Kwlw      Warnbro NaN NaN
# 99   SN786  384139.0  6532149.0    54.0 -1180.0     Kwlw      Warnbro NaN NaN
# 108    AM1  356924.0  6531829.0  -446.0 -1280.0     Kwlw      Warnbro NaN NaN
# 123    GB5  395149.0  6531407.0    21.0 -1280.0     Kwlw      Warnbro NaN NaN
# 138   MCK1  401021.0  6531105.0   -53.0 -1180.0     Kwlw      Warnbro NaN NaN
# 147    GB1  401258.0  6530836.0   -67.0 -1180.0     Kwlw      Warnbro NaN NaN
# 166    AM2  365646.0  6529649.0  -569.0 -1280.0     Kwlw      Warnbro NaN NaN
# 176    AM6  386985.0  6529614.0   -16.0 -1280.0     Kwlw      Warnbro NaN NaN
# 188   DELE  398539.0  6529149.0    17.0 -1180.0     Kwlw      Warnbro NaN NaN
# 195   GASB  398539.0  6528649.0     7.0 -1180.0     Kwlw      Warnbro NaN NaN
# 203   AM76  372107.1  6528279.3 -525.43 -1280.0     Kwlw      Warnbro NaN NaN
# 213   PB5A  400539.0  6528049.0   113.0 -1180.0     Kwlw      Warnbro NaN NaN
# 218    AM5  375480.0  6527971.0  -190.0 -1280.0     Kwlw      Warnbro NaN NaN
# 228    AM7  398727.0  6527718.0  -204.0 -1280.0     Kwlw      Warnbro NaN NaN
# 240    TTD  400789.0  6527699.0   -27.0 -1180.0     Kwlw      Warnbro NaN NaN
# 250   POL2  400639.0  6527649.0   -95.0 -1180.0     Kwlw      Warnbro NaN NaN
# 256    PB3  399819.0  6527569.0    18.0 -1180.0     Kwlw      Warnbro NaN NaN
# 261   AVON  398039.0  6527349.0    21.0 -1180.0     Kwlw      Warnbro NaN NaN
#
#      gz
# 9   NaN
# 16  NaN
# 26  NaN
# 43  NaN
# 49  NaN
# 69  NaN
# 75  NaN
# 92  NaN
# 99  NaN
# 108 NaN
# 123 NaN
# 138 NaN
# 147 NaN
# 166 NaN
# 176 NaN
# 188 NaN
# 195 NaN
# 203 NaN
# 213 NaN
# 218 NaN
# 228 NaN
# 240 NaN
# 250 NaN
# 256 NaN
# 261 NaN
#
#  Lithology =  Kwlm
#
#         ID         X          Y        Z     val lithcode feature_name  gx  gy  \
# 10    AM3  367173.0  6535521.0   -579.0 -1280.0     Kwlm      Warnbro NaN NaN
# 17    AM4  383790.0  6535459.0   -150.0 -1380.0     Kwlm      Warnbro NaN NaN
# 50    GB3  373194.0  6533955.0   -329.0 -1380.0     Kwlm      Warnbro NaN NaN
# 76    GB2  366379.0  6533124.0   -110.0 -1380.0     Kwlm      Warnbro NaN NaN
# 109   AM1  356924.0  6531829.0   -452.0 -1380.0     Kwlm      Warnbro NaN NaN
# 167   AM2  365646.0  6529649.0   -739.0 -1380.0     Kwlm      Warnbro NaN NaN
# 204  AM76  372107.1  6528279.3  -525.43 -1280.0     Kwlm      Warnbro NaN NaN
# 219   AM5  375480.0  6527971.0   -225.0 -1380.0     Kwlm      Warnbro NaN NaN
#
#      gz
# 10  NaN
# 17  NaN
# 50  NaN
# 76  NaN
# 109 NaN
# 167 NaN
# 204 NaN
# 219 NaN
#
#  Lithology =  Kws
#
#        ID         X          Y      Z     val lithcode feature_name  gx  gy  gz
# 18   AM4  383790.0  6535459.0 -154.0 -1480.0      Kws      Warnbro NaN NaN NaN
# 51   GB3  373194.0  6533955.0 -345.0 -1480.0      Kws      Warnbro NaN NaN NaN
# 110  AM1  356924.0  6531829.0 -464.0 -1480.0      Kws      Warnbro NaN NaN NaN
# 168  AM2  365646.0  6529649.0 -767.0 -1480.0      Kws      Warnbro NaN NaN NaN
#
#  Lithology =  Kwg
#
#        ID         X          Y      Z     val lithcode feature_name  gx  gy  gz
# 19   AM4  383790.0  6535459.0 -282.0 -1580.0      Kwg      Warnbro NaN NaN NaN
# 52   GB3  373194.0  6533955.0 -374.0 -1580.0      Kwg      Warnbro NaN NaN NaN
# 169  AM2  365646.0  6529649.0 -793.0 -1580.0      Kwg      Warnbro NaN NaN NaN
#
#  Lithology =  Kpc
#
#         ID         X          Y       Z     val lithcode feature_name   gx  \
# 32    GY1  392430.0  6534424.0 -469.52 -1680.0      Kpc   Yarragadee  0.0
# 94   GG75  396339.0  6532249.0   -56.0 -1580.0      Kpc   Yarragadee  0.0
# 112   AM1  356924.0  6531829.0  -464.0 -1580.0      Kpc   Yarragadee  0.0
# 125   GB5  395149.0  6531407.0  -277.0 -1680.0      Kpc   Yarragadee  0.0
# 230   AM7  398727.0  6527718.0  -204.0 -1580.0      Kpc   Yarragadee  0.0
#
#       gy   gz
# 32   0.0  1.0
# 94   0.0  1.0
# 112  0.0  1.0
# 125  0.0  1.0
# 230  0.0  1.0
#
#  Lithology =  Kps
#
#        ID         X          Y      Z     val lithcode feature_name   gx   gy  \
# 126  GB5  395149.0  6531407.0 -348.0 -1780.0      Kps   Yarragadee  0.0  0.0
#
#       gz
# 126  1.0
#
#  Lithology =  Kpo
#
#        ID         X          Y      Z     val lithcode feature_name   gx   gy  \
# 127  GB5  395149.0  6531407.0 -411.0 -1880.0      Kpo   Yarragadee  0.0  0.0
#
#       gz
# 127  1.0
#
#  Lithology =  Jy
#
#        ID         X          Y        Z     val lithcode feature_name   gx  \
# 21   AM4  383790.0  6535459.0   -282.0 -1880.0       Jy   Yarragadee  0.0
# 33   GY1  392430.0  6534424.0  -469.52 -1880.0       Jy   Yarragadee  0.0
# 54   GB3  373194.0  6533955.0   -374.0 -1880.0       Jy   Yarragadee  0.0
# 78   GB2  366379.0  6533124.0   -110.0 -1880.0       Jy   Yarragadee  0.0
# 128  GB5  395149.0  6531407.0   -411.0 -1880.0       Jy   Yarragadee  0.0
# 171  AM2  365646.0  6529649.0   -793.0 -1880.0       Jy   Yarragadee  0.0
# 178  AM6  386985.0  6529614.0    -16.0 -1880.0       Jy   Yarragadee  0.0
# 221  AM5  375480.0  6527971.0   -225.0 -1880.0       Jy   Yarragadee  0.0
#
#       gy   gz
# 21   0.0  1.0
# 33   0.0  1.0
# 54   0.0  1.0
# 78   0.0  1.0
# 128  0.0  1.0
# 171  0.0  1.0
# 178  0.0  1.0
# 221  0.0  1.0
#
#  Lithology =  Jc
#
#  Empty DataFrame
# Columns: [ID, X, Y, Z, val, lithcode, feature_name, gx, gy, gz]
# Index: []

# %% [markdown]
# ### Create Geomodel

# %%
from LoopStructural import GeologicalModel
origin  = (x0, y0, z0)
maximum = (x1, y1, z1)
geomodel = GeologicalModel(origin, maximum)
geomodel.data = data

# %% [markdown]
# ### Add surfaces

# %%
Quaternary = geomodel.create_and_add_foliation("Quaternary", nelements=1e5)
QuatUC     = geomodel.add_unconformity(Quaternary, strat.vals[1]) # Clips above #(UC0)

Coolyena = geomodel.create_and_add_foliation("Coolyena",nelements=1e5)

CoolUC   = geomodel.create_and_add_foliation("CoolUC",nelements=1e5)
UC1  = geomodel.add_unconformity(CoolUC, 0.)

Warnbro = geomodel.create_and_add_foliation("Warnbro",nelements=1e5)

WarnUC = geomodel.create_and_add_foliation("WarnUC",nelements=1e5)
UC2  = geomodel.add_unconformity(WarnUC, 0.)

Yarragadee = geomodel.create_and_add_foliation("Yarragadee",nelements=1e5)

print(data.feature_name.unique())
# Out:
# Cannot use region
# Cannot use region
# Cannot use region
# Cannot use region
# Cannot use region
# Cannot use region
# Cannot use region
# Cannot use region
# Cannot use region
# Cannot use region
# Cannot use region
# Cannot use region
# ['Quaternary' 'Tertiary_unconformity' 'Coolyena' 'CoolUC' 'Warnbro'
#  'WarnUC' 'Yarragadee']

# %% [markdown]
# ### Add Stratigraphy Column

# %%
stratigraphic_column = {}
stratigraphic_column["Quaternary"] = {}
stratigraphic_column["Tertiary"] = {}
stratigraphic_column["Coolyena"] = {}
stratigraphic_column["Warnbro"] = {}
stratigraphic_column["Yarragadee"] = {}

for i in range(len(lithcodes)-1):

    sequence = strat.iloc[i].sequences
    lith     = strat.iloc[i].lithcode
    lithid   = strat.iloc[i].lithid
    color    = strat.iloc[i].color  
    
    if i == 0: # Top unit
        minval   = strat.iloc[i].vals
        stratigraphic_column[sequence][lith] = {'min':minval,'max':np.inf,'id':lithid, 'color':color} 
  
    if i > 0 and i < len(lithcodes)-1 : # middle units
        minval   = strat.iloc[i].vals
        maxval   = strat.iloc[i-1].vals
        stratigraphic_column[sequence][lith] = {'min':minval,'max':maxval,'id':lithid, 'color':color}
        
    if i == len(lithcodes)-1: # Bottom unit
        maxval   = strat.iloc[i-1].vals
        stratigraphic_column[sequence][lith] = {'min':-np.inf,'max':maxval,'id':lithid,  'color':color}   
    
geomodel.set_stratigraphic_column(stratigraphic_column)

#stratigraphic_column

# %%
'''stratigraphic_column = {}
stratigraphic_column["Quaternary"] = {}
stratigraphic_column["Quaternary"]["Ground"] =  {'min':strat.vals[0],'max':np.inf,'id':-1}
stratigraphic_column["Quaternary"]["TQ"]     =  {'min':strat.vals[1],'max':strat.vals[0],'id':0}

stratigraphic_column["Coolyena"] = {}
stratigraphic_column["Coolyena"]["Kcl"] =  {'min':strat.vals[2],'max':strat.vals[1], 'id':1}
stratigraphic_column["Coolyena"]["Kcp"] =  {'min':strat.vals[3],'max':strat.vals[2],'id':2}
stratigraphic_column["Coolyena"]["Kcg"] =  {'min':strat.vals[4],'max':strat.vals[3],'id':3}
stratigraphic_column["Coolyena"]["Kcm"] =  {'min':strat.vals[5],'max':strat.vals[4],'id':4}
stratigraphic_column["Coolyena"]["Kcom"] = {'min':strat.vals[6],'max':strat.vals[5],'id':5}
stratigraphic_column["Coolyena"]["Kcok"] = {'min':strat.vals[7],'max':strat.vals[6],'id':6}
stratigraphic_column["Coolyena"]["Kcoh"] = {'min':strat.vals[8],'max':strat.vals[7],'id':7}

stratigraphic_column["Warnbro"] = {}
stratigraphic_column["Warnbro"]["Kwlp"] =  {'min':strat.vals[9],'max':strat.vals[8], 'id':8}
stratigraphic_column["Warnbro"]["Kwlw"] =  {'min':strat.vals[10],'max':strat.vals[9],'id':9}
stratigraphic_column["Warnbro"]["Kwlm"] =  {'min':strat.vals[11],'max':strat.vals[10],'id':10}
stratigraphic_column["Warnbro"]["Kws"] =   {'min':strat.vals[12],'max':strat.vals[11],'id':11}
stratigraphic_column["Warnbro"]["Kwg"] =   {'min':strat.vals[13],'max':strat.vals[12],'id':12}

stratigraphic_column["Yarragadee"] = {}
stratigraphic_column["Yarragadee"]["Kpc"] = {'min':strat.vals[14],'max':strat.vals[13], 'id':13}
stratigraphic_column["Yarragadee"]["Kps"] = {'min':strat.vals[15],'max':strat.vals[14],'id':14}
stratigraphic_column["Yarragadee"]["Kpo"] = {'min':strat.vals[16],'max':strat.vals[15],'id':15}
stratigraphic_column["Yarragadee"]["Jy"]  = {'min':strat.vals[17],'max':strat.vals[16],'id':16}
stratigraphic_column["Yarragadee"]["Jc"]  = {'min':-np.inf,'max':strat.vals[17],'id':17}

geomodel.set_stratigraphic_column(stratigraphic_column)'''
# Out:
# 'stratigraphic_column = {}\nstratigraphic_column["Quaternary"] = {}\nstratigraphic_column["Quaternary"]["Ground"] =  {\'min\':strat.vals[0],\'max\':np.inf,\'id\':-1}\nstratigraphic_column["Quaternary"]["TQ"]     =  {\'min\':strat.vals[1],\'max\':strat.vals[0],\'id\':0}\n\nstratigraphic_column["Coolyena"] = {}\nstratigraphic_column["Coolyena"]["Kcl"] =  {\'min\':strat.vals[2],\'max\':strat.vals[1], \'id\':1}\nstratigraphic_column["Coolyena"]["Kcp"] =  {\'min\':strat.vals[3],\'max\':strat.vals[2],\'id\':2}\nstratigraphic_column["Coolyena"]["Kcg"] =  {\'min\':strat.vals[4],\'max\':strat.vals[3],\'id\':3}\nstratigraphic_column["Coolyena"]["Kcm"] =  {\'min\':strat.vals[5],\'max\':strat.vals[4],\'id\':4}\nstratigraphic_column["Coolyena"]["Kcom"] = {\'min\':strat.vals[6],\'max\':strat.vals[5],\'id\':5}\nstratigraphic_column["Coolyena"]["Kcok"] = {\'min\':strat.vals[7],\'max\':strat.vals[6],\'id\':6}\nstratigraphic_column["Coolyena"]["Kcoh"] = {\'min\':strat.vals[8],\'max\':strat.vals[7],\'id\':7}\n\nstratigraphic_column["Warnbro"] = {}\nstratigraphic_column["Warnbro"]["Kwlp"] =  {\'min\':strat.vals[9],\'max\':strat.vals[8], \'id\':8}\nstratigraphic_column["Warnbro"]["Kwlw"] =  {\'min\':strat.vals[10],\'max\':strat.vals[9],\'id\':9}\nstratigraphic_column["Warnbro"]["Kwlm"] =  {\'min\':strat.vals[11],\'max\':strat.vals[10],\'id\':10}\nstratigraphic_column["Warnbro"]["Kws"] =   {\'min\':strat.vals[12],\'max\':strat.vals[11],\'id\':11}\nstratigraphic_column["Warnbro"]["Kwg"] =   {\'min\':strat.vals[13],\'max\':strat.vals[12],\'id\':12}\n\nstratigraphic_column["Yarragadee"] = {}\nstratigraphic_column["Yarragadee"]["Kpc"] = {\'min\':strat.vals[14],\'max\':strat.vals[13], \'id\':13}\nstratigraphic_column["Yarragadee"]["Kps"] = {\'min\':strat.vals[15],\'max\':strat.vals[14],\'id\':14}\nstratigraphic_column["Yarragadee"]["Kpo"] = {\'min\':strat.vals[16],\'max\':strat.vals[15],\'id\':15}\nstratigraphic_column["Yarragadee"]["Jy"]  = {\'min\':strat.vals[17],\'max\':strat.vals[16],\'id\':16}\nstratigraphic_column["Yarragadee"]["Jc"]  = {\'min\':-np.inf,\'max\':strat.vals[17],\'id\':17}\n\ngeomodel.set_stratigraphic_column(stratigraphic_column)'

# %%
#stratigraphic_column

# %% [markdown]
# ### 3D View

# %%
# View "model surfaces"
figure = True ### LavaVu Geo model 3D
if figure:
    from LoopStructural.visualisation import LavaVuModelViewer
    view = LavaVuModelViewer(geomodel, background='white')
    view.interactive(popout=True) 
    view.add_model_surfaces(faults = False, cmap = 'Spectral') #faults=False
    #view.add_isosurface(Fault,isovalue=0)
    view.set_zscale(zscale = 10)
    #view.add_points(points = np.array(fault_plane_3d), name = 'fault')
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# WARNING: 2024-03-21 23:38:10,197: model_plotter.py:355 -- Yarragadee: Isovalue doesn't exist inside bounding box

# %% [markdown]
# ### 2D View

# %%
#from matplotlib.colors import ListedColormap
#import matplotlib.colors
#colors = list(zip(strat.R, strat.G, strat.B))
#cmap = ListedColormap(colors, name='perth_geo')
#labels = np.copy(lithcodes)

strat
# Out:
#     index  lithid lithcode   sequences  vals               color
# 0       0      -1   Ground  Quaternary   120     [1.0, 1.0, 1.0]
# 1       1       0       TQ  Quaternary    20     [1.0, 1.0, 0.0]
# 2       2       1       Tr    Tertiary   -80   [0.73, 0.6, 0.58]
# 3       3       2      Tkm    Tertiary  -180     [1.0, 0.6, 0.2]
# 4       4       3       Tk    Tertiary  -280  [1.12, 0.32, 0.16]
# 5       5       4      Tkc    Tertiary  -380     [1.0, 0.6, 0.2]
# 6       6       5      Kcl    Coolyena  -480    [0.67, 0.8, 0.0]
# 7       7       6      Kcp    Coolyena  -580  [0.77, 0.84, 0.61]
# 8       8       7      Kcg    Coolyena  -680   [0.67, 0.85, 0.6]
# 9       9       8      Kcm    Coolyena  -780  [0.67, 0.78, 0.71]
# 10     10       9     Kcom    Coolyena  -880   [0.66, 0.64, 0.0]
# 11     11      10     Kcok    Coolyena  -980     [1.0, 0.8, 0.6]
# 12     12      11     Kcoh    Coolyena -1080     [1.0, 0.8, 0.8]
# 13     13      12     Kwlp     Warnbro -1180     [0.8, 1.0, 0.2]
# 14     14      13     Kwlw     Warnbro -1280     [0.6, 0.8, 0.0]
# 15     15      14     Kwlm     Warnbro -1380     [0.4, 0.6, 0.0]
# 16     16      15      Kws     Warnbro -1480  [0.58, 0.54, 0.33]
# 17     17      16      Kwg     Warnbro -1580   [0.31, 0.38, 0.2]
# 18     18      17      Kpc  Yarragadee -1680  [0.68, 0.73, 0.95]
# 19     19      18      Kps  Yarragadee -1780  [0.68, 0.73, 0.95]
# 20     20      19      Kpo  Yarragadee -1880    [0.46, 0.5, 0.9]
# 21     21      20       Jy  Yarragadee -1980  [0.33, 0.55, 0.83]
# 22     22      21       Jc  Yarragadee -2080   [0.0, 0.63, 0.72]

# %%
y_transects = [6505000, 6515000, 6525000]
Quaternary_levels = [strat.vals[1], strat.vals[0], 9999]
Coolyena_levels = [strat.vals[5], strat.vals[4], strat.vals[3], strat.vals[2], strat.vals[1], 9999]
Warnbro_levels = [strat.vals[10], strat.vals[9], strat.vals[8], strat.vals[7], strat.vals[6], strat.vals[5], 9999]
Yarragadee_levels =[-9999, strat.vals[10], 9999]

figure = True
if figure == True:   
    
    fig, ax = plt.subplots(3,1,figsize=(6,6))

    delx, delz = 100, 100
    x, z = np.linspace(x0,x1,delx), np.linspace(z0,z1,delz)
    xx, zz = np.meshgrid(x,z)
    yy = np.zeros_like(xx)
    yy[:] = y_transects[0]
    ax[0].set_title('Section A (y = %i)' %y_transects[0])

    vals1 = geomodel.evaluate_feature_value('Quaternary',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[0].contourf(vals1.reshape((delx, delz)), levels = Quaternary_levels, extent=(x0, x1, z0, z1))
    vals2 = geomodel.evaluate_feature_value('Coolyena',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[0].contourf(vals2.reshape((delx, delz)), levels = Coolyena_levels, extent=(x0, x1, z0, z1))
    vals3 = geomodel.evaluate_feature_value('Warnbro',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[0].contourf(vals3.reshape((delx, delz)), levels = Warnbro_levels, extent=(x0, x1, z0, z1))
    vals4 = geomodel.evaluate_feature_value('Yarragadee',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[0].contourf(vals4.reshape((delx, delz)), levels = Yarragadee_levels, extent=(x0, x1, z0, z1))
    
    yy[:] = y_transects[1]
    ax[1].set_title('Section B (y = %i)' %y_transects[1])

    vals1 = geomodel.evaluate_feature_value('Quaternary',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[1].contourf(vals1.reshape((delx, delz)), levels = Quaternary_levels, extent=(x0, x1, z0, z1))
    vals2 = geomodel.evaluate_feature_value('Coolyena',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[1].contourf(vals2.reshape((delx, delz)), levels = Coolyena_levels, extent=(x0, x1, z0, z1))
    vals3 = geomodel.evaluate_feature_value('Warnbro',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[1].contourf(vals3.reshape((delx, delz)), levels = Warnbro_levels, extent=(x0, x1, z0, z1))

    yy = np.zeros_like(xx)
    yy[:] = y_transects[2]
    ax[2].set_title('Section C (y = %i)' %y_transects[2])

    vals1 = geomodel.evaluate_feature_value('Quaternary',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[2].contourf(vals1.reshape((delx, delz)), levels = Quaternary_levels, extent=(x0, x1, z0, z1))
    vals2 = geomodel.evaluate_feature_value('Coolyena',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[2].contourf(vals2.reshape((delx, delz)), levels = Coolyena_levels, extent=(x0, x1, z0, z1))
    vals3 = geomodel.evaluate_feature_value('Warnbro',np.array([xx.flatten(),yy.flatten(),zz.flatten()]).T)
    ax[2].contourf(vals3.reshape((delx, delz)), levels = Warnbro_levels, extent=(x0, x1, z0, z1))

    plt.tight_layout() 
    plt.show()
# Out:
# C:\Users\00098687\Anaconda3\envs\loop3denv\lib\site-packages\matplotlib\contour.py:1454: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\00098687\Anaconda3\envs\loop3denv\lib\site-packages\matplotlib\contour.py:1455: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())

# %%
delx, delz = 500, 50
print((x1-x0)/delx)
print((z1-z0)/delz)
# Out:
# 70.0
# 28.0

# %%
print(one.reshape(np.shape(Z)))

import matplotlib.pyplot as plt
plt.imshow(Xsect.reshape(np.shape(Z)),origin = 'lower')#, extent = [x[0],x[-1],z[0],z[-1]])
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35000\310505042.py in <cell line: 1>()
# ----> 1 print(one.reshape(np.shape(Z)))
#       2
#       3 import matplotlib.pyplot as plt
#       4 plt.imshow(Xsect.reshape(np.shape(Z)),origin = 'lower')#, extent = [x[0],x[-1],z[0],z[-1]])
#       5 plt.colorbar()
#
# NameError: name 'one' is not defined

# %%
model.evaluate_model([(350439.0,6566450.0,-500.0)])

# %%
len(x)
